# %%
import torch
from torch.distributions.multinomial import Multinomial

# %%
Multinomial(7, torch.tensor([0.9, 0.4])).sample()
# Out:
# tensor([4., 3.])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the vector-valued function
def r(t):
    x = t
    y = t**2
    z = np.sin(t)
    return np.array([x, y, z])

# Generate values for t
t_values = np.linspace(0, 2*np.pi, 100)

# Calculate the corresponding r(t) values
r_values = np.array([r(t) for t in t_values])

# Plot the vector-valued function
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(r_values[:,0], r_values[:,1], r_values[:,2])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Graph of the Vector-Valued Function r(t) = [t, t^2, sin(t)]')

plt.show()
